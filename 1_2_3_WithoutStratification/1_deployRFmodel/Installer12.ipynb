# %%
pip install padelpy
# Out:
# ...
#    ---------------------------------------- 0.0/20.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/20.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/20.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/20.9 MB 325.1 kB/s eta 0:01:05
#    ---------------------------------------- 0.1/20.9 MB 558.5 kB/s eta 0:00:38
#    ---------------------------------------- 0.1/20.9 MB 798.9 kB/s eta 0:00:26
#    ---------------------------------------- 0.2/20.9 MB 833.5 kB/s eta 0:00:25
#    ---------------------------------------- 0.2/20.9 MB 958.4 kB/s eta 0:00:22
#    ---------------------------------------- 0.3/20.9 MB 983.0 kB/s eta 0:00:21
#    ---------------------------------------- 0.3/20.9 MB 983.0 kB/s eta 0:00:21
#     --------------------------------------- 0.3/20.9 MB 1.0 MB/s eta 0:00:20
#     --------------------------------------- 0.4/20.9 MB 1.1 MB/s eta 0:00:19
# ...

# %%
pip install joblib
# Out:
# ...
#    ---------------------------------------- 0.0/302.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/302.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/302.2 kB ? eta -:--:--
#    - -------------------------------------- 10.2/302.2 kB ? eta -:--:--
#    - -------------------------------------- 10.2/302.2 kB ? eta -:--:--
#    - -------------------------------------- 10.2/302.2 kB ? eta -:--:--
#    - -------------------------------------- 10.2/302.2 kB ? eta -:--:--
#    --- ----------------------------------- 30.7/302.2 kB 131.3 kB/s eta 0:00:03
#    ----- --------------------------------- 41.0/302.2 kB 151.3 kB/s eta 0:00:02
#    --------- ----------------------------- 71.7/302.2 kB 245.8 kB/s eta 0:00:01
#    --------------- ---------------------- 122.9/302.2 kB 400.9 kB/s eta 0:00:01
#    --------------------- ---------------- 174.1/302.2 kB 499.5 kB/s eta 0:00:01
# ...

# %%
pip install -U scikit-learn
# Out:
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.0 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/61.0 kB 435.7 kB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 466.1 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      ------------------------- ------------ 41.0/60.4 kB 960.0 kB/s eta 0:00:01
#      -------------------------------------- 60.4/60.4 kB 796.9 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB 991.0 kB/s eta 0:00:11
#    ---------------------------------------- 0.1/10.6 MB 1.1 MB/s eta 0:00:10
# ...
